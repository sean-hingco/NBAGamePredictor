# %%
from nba_api.stats.endpoints import leaguegamefinder
from nba_api.stats.static import teams
from nba_api.stats.endpoints import boxscoretraditionalv3
import pandas as pd
import datetime
import time

# %%
import pandas as pd

# get all NBA teams
nba_teams = teams.get_teams()
teams_df = pd.DataFrame(nba_teams)

# save team IDs and names
team_ids = teams_df['id'].tolist()

teams_df.head()
# Out:
#            id             full_name abbreviation   nickname         city  \
# 0  1610612737         Atlanta Hawks          ATL      Hawks      Atlanta
# 1  1610612738        Boston Celtics          BOS    Celtics       Boston
# 2  1610612739   Cleveland Cavaliers          CLE  Cavaliers    Cleveland
# 3  1610612740  New Orleans Pelicans          NOP   Pelicans  New Orleans
# 4  1610612741         Chicago Bulls          CHI      Bulls      Chicago
#
#            state  year_founded
# 0        Georgia          1949
# 1  Massachusetts          1946
# 2           Ohio          1970
# 3      Louisiana          2002
# 4       Illinois          1966

# %%
# get current season
current_year = datetime.datetime.now().year
current_month = datetime.datetime.now().month
season_id = f"2{current_year - 1}" if current_month < 10 else f"2{current_year}"

# get schedules for all seasons
all_games = []

for team_id in team_ids:
    gamefinder = leaguegamefinder.LeagueGameFinder(team_id_nullable=team_id)
    games = gamefinder.get_data_frames()[0]
    games_current_season = games[games['SEASON_ID'] == season_id]  # Filter for current season
    all_games.append(games_current_season)

# collect team schedules into single dataframe
games_df = pd.concat(all_games, ignore_index=True)

# save data and view
games_df.to_csv(f'games_{season_id}.csv', index=False)
games_df.head()
# Out:
#   SEASON_ID     TEAM_ID TEAM_ABBREVIATION      TEAM_NAME     GAME_ID  \
# 0     22024  1610612737               ATL  Atlanta Hawks  0022400701
# 1     22024  1610612737               ATL  Atlanta Hawks  0022400686
# 2     22024  1610612737               ATL  Atlanta Hawks  0022400675
# 3     22024  1610612737               ATL  Atlanta Hawks  0022400532
# 4     22024  1610612737               ATL  Atlanta Hawks  0022400656
#
#     GAME_DATE      MATCHUP WL  MIN  PTS  ...  FT_PCT  OREB  DREB   REB  AST  \
# 0  2025-02-03    ATL @ DET  W  240  132  ...   0.821   5.0  32.0  37.0   27
# 1  2025-02-01    ATL @ IND  L  240  127  ...   0.719  11.0  33.0  44.0   31
# 2  2025-01-30    ATL @ CLE  L  240  115  ...   0.741  10.0  26.0  36.0   28
# 3  2025-01-28  ATL vs. HOU  L  240   96  ...   0.813   9.0  31.0  40.0   19
# 4  2025-01-27    ATL @ MIN  L  241   92  ...   0.667  14.0  37.0  51.0   24
#
#     STL  BLK  TOV  PF  PLUS_MINUS
# 0   8.0    7   12  27         2.0
# 1   6.0    4   12  23        -5.0
# 2  10.0    1   11  18       -22.0
# 3  11.0    5   16  18        -4.0
# 4  10.0    3   21  20        -8.0
#
# [5 rows x 28 columns]

# %%
# get player stats
all_player_stats = []

for index, row in games_df.iterrows():
    print(f'on game {row["GAME_ID"]}')
    game_id = row['GAME_ID']
    try:
        # fetch box score for the game
        boxscore = boxscoretraditionalv3.BoxScoreTraditionalV3(game_id=game_id)
        player_stats = boxscore.player_stats.get_data_frame()

        # add game context to player stats
        player_stats['GAME_ID'] = game_id
        player_stats['GAME_DATE'] = row['GAME_DATE']
        player_stats['TEAM_NAME'] = row['TEAM_NAME']
        all_player_stats.append(player_stats)

        # respect API rate limits
        time.sleep(1)

    except Exception as e:
        print(f"Error fetching player stats for game {game_id}: {e}")

# collect player stats into single dataframe
player_stats_df = pd.concat(all_player_stats, ignore_index=True)

# save data and view
player_stats_df.to_csv(f'player_stats_{season_id}.csv', index=False)
player_stats_df.head()
# Out:
# on game 0022400701
# on game 0022400686
# on game 0022400675
# on game 0022400532
# on game 0022400656
# on game 0022400639
# on game 0022400623
# on game 0022400612
# on game 0022400602
# on game 0022400587
# on game 0022400563
# on game 0022400556
# on game 0022400522
# on game 0022400506
# on game 0022400486
# on game 0022400477
# on game 0022400461
# on game 0022400438
# on game 0022400427
# on game 0022400413
# on game 0022400395
# on game 0022400378
# on game 0022400370
# on game 0022401229
# on game 0022401202
# on game 0022400350
# on game 0022400334
# on game 0022400323
# on game 0022400315
# on game 0022400300
# on game 0022400041
# on game 0022400287
# on game 0022400280
# on game 0022400030
# on game 0022400258
# on game 0022400250
# on game 0022400239
# on game 0022400012
# on game 0022400001
# on game 0022400198
# on game 0022400185
# on game 0022400171
# on game 0022400157
# on game 0022400152
# on game 0022400135
# on game 0022400121
# on game 0022400103
# on game 0022400100
# on game 0022400079
# on game 0022400064
# on game 1522400064
# on game 1522400055
# on game 1522400044
# on game 1522400021
# on game 1522400006
# on game 0022400710
# on game 0022400698
# on game 0022400683
# on game 0022400666
# on game 0022400650
# on game 0022400635
# on game 0022400629
# on game 0022400620
# on game 0022400604
# on game 0022400587
# on game 0022400577
# on game 0022400562
# on game 0022400542
# on game 0022400528
# on game 0022400507
# on game 0022400487
# on game 0022400471
# on game 0022400464
# on game 0022400449
# on game 0022400437
# on game 0022400420
# on game 0022400407
# on game 0022400393
# on game 0022400381
# on game 0022400363
# on game 0022401217
# on game 0022401205
# on game 0022400345
# on game 0022400335
# on game 0022400319
# on game 0022400316
# on game 0022400307
# on game 0022400047
# on game 0022400281
# on game 0022400271
# on game 0022400028
# on game 0022400021
# on game 0022400230
# on game 0022400218
# on game 0022400001
# on game 0022400202
# on game 0022400187
# on game 0022400172
# on game 0022400157
# on game 0022400141
# on game 0022400132
# on game 0022400119
# on game 0022400104
# on game 0022400089
# on game 0022400073
# on game 0022400061
# on game 1522400071
# on game 1522400054
# on game 1522400041
# on game 1522400029
# on game 1522400010
# on game 0022400710
# on game 0022400696
# on game 0022400675
# on game 0022400667
# on game 0022400649
# on game 0022400640
# on game 0022400631
# on game 0022400615
# on game 0022400603
# on game 0022400590
# on game 0022400574
# on game 0022400554
# on game 0022400543
# on game 0022400517
# on game 0022400509
# on game 0022400488
# on game 0022400474
# on game 0022400454
# on game 0022400446
# on game 0022400424
# on game 0022400392
# on game 0022400380
# on game 0022400374
# on game 0022401224
# on game 0022401208
# on game 0022400351
# on game 0022400340
# on game 0022400325
# on game 0022400051
# on game 0022400307
# on game 0022400041
# on game 0022400287
# on game 0022400275
# on game 0022400252
# on game 0022400021
# on game 0022400236
# on game 0022400013
# on game 0022400220
# on game 0022400212
# on game 0022400199
# on game 0022400188
# on game 0022400175
# on game 0022400154
# on game 0022400145
# on game 0022400133
# on game 0022400118
# on game 0022400106
# on game 0022400090
# on game 0022400080
# Error fetching player stats for game 0022400080: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# on game 0022400067
# on game 1522400063
# on game 1522400050
# on game 1522400045
# on game 1522400016
# on game 1522400001
# on game 0022400706
# on game 0022400683
# on game 0022400670
# on game 0022400654
# on game 0022400637
# on game 0022400632
# on game 0022400605
# on game 0022400581
# on game 0022400566
# on game 0022400557
# on game 0022400542
# on game 0022400527
# on game 0022400514
# on game 0022400505
# on game 0022400489
# on game 0022400472
# on game 0022400457
# on game 0022400444
# on game 0022400423
# on game 0022400416
# on game 0022400390
# on game 0022400384
# on game 0022400365
# on game 0022401216
# on game 0022401207
# on game 0022400354
# on game 0022400342
# on game 0022400330
# on game 0022400315
# on game 0022400308
# on game 0022400042
# on game 0022400295
# on game 0022400279
# on game 0022400032
# on game 0022400252
# on game 0022400024
# on game 0022400231
# on game 0022400017
# on game 0022400221
# on game 0022400214
# on game 0022400186
# on game 0022400175
# on game 0022400164
# on game 0022400152
# on game 0022400138
# on game 0022400126
# on game 0022400116
# on game 0022400099
# on game 0022400086
# on game 0022400069
# on game 1522400066
# on game 1522400047
# on game 1522400037
# on game 1522400020
# on game 1522400002
# on game 0022400714
# on game 0022400695
# on game 0022400682
# on game 0022400666
# on game 0022400655
# on game 0022400642
# on game 0022400628
# on game 0022400611
# on game 0022400597
# on game 0022400584
# on game 0022400563
# on game 0022400557
# on game 0022400541
# on game 0022400530
# on game 0022400510
# on game 0022400498
# on game 0022400482
# on game 0022400456
# on game 0022400442
# on game 0022400430
# on game 0022400413
# on game 0022400398
# on game 0022400381
# on game 0022400363
# on game 0022401223
# on game 0022401212
# on game 0022400347
# on game 0022400336
# on game 0022400331
# on game 0022400317
# on game 0022400047
# on game 0022400289
# on game 0022400035
# on game 0022400266
# on game 0022400030
# on game 0022400253
# on game 0022400244
# on game 0022400241
# on game 0022400013
# on game 0022400219
# on game 0022400212
# on game 0022400198
# on game 0022400181
# on game 0022400176
# on game 0022400160
# on game 0022400136
# on game 0022400123
# on game 0022400108
# on game 0022400091
# on game 0022400083
# on game 0022400069
# on game 1522400065
# on game 1522400055
# on game 1522400033
# on game 1522400023
# on game 1522400008
# on game 0022400712
# on game 0022400696
# on game 0022400680
# on game 0022400670
# on game 0022400657
# on game 0022400635
# on game 0022400625
# on game 0022400614
# on game 0022400599
# on game 0022400583
# on game 0022400566
# on game 0022400559
# on game 0022400540
# on game 0022400521
# on game 0022400504
# on game 0022400499
# on game 0022400474
# on game 0022400460
# on game 0022400448
# on game 0022400434
# on game 0022400425
# on game 0022400406
# on game 0022400401
# on game 0022400385
# on game 0022400368
# on game 0022401228
# on game 0022401203
# on game 0022400344
# on game 0022400326
# on game 0022400056
# on game 0022400312
# on game 0022400304
# on game 0022400292
# on game 0022400280
# on game 0022400273
# on game 0022400033
# on game 0022400024
# on game 0022400242
# on game 0022400232
# on game 0022400228
# on game 0022400007
# on game 0022400208
# on game 0022400190
# on game 0022400176
# on game 0022400165
# on game 0022400153
# on game 0022400129
# on game 0022400114
# on game 0022400110
# on game 0022400095
# on game 0022400074
# on game 1522400067
# on game 1522400067
# on game 1522400054
# on game 1522400038
# on game 1522400026
# on game 1522400026
# on game 1522400014
# on game 0022400706
# on game 0022400688
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[177], line 19
#      16     all_player_stats.append(player_stats)
#      18     # respect API rate limits
# ---> 19     time.sleep(1)
#      21 except Exception as e:
#      22     print(f"Error fetching player stats for game {game_id}: {e}")
#
# KeyboardInterrupt:

# %%
duplicates = player_stats_df.duplicated(subset=['gameId', 'personId'], keep=False)
player_stats_cleaned = player_stats_df.drop_duplicates(subset=['gameId', 'personId'], keep='first')
print(f'player_stats_df: {len(player_stats_df)}         player_stats_cleaned: {len(player_stats_cleaned)}')
# Out:
# player_stats_df: 15952         player_stats_cleaned: 12470

# %%
player_stats_cleaned.head()
# Out:
#        gameId      teamId teamCity teamName teamTricode teamSlug  personId  \
# 0  0022400563  1610612737  Atlanta    Hawks         ATL    hawks   1630249
# 1  0022400563  1610612737  Atlanta    Hawks         ATL    hawks   1631223
# 2  0022400563  1610612737  Atlanta    Hawks         ATL    hawks    203991
# 3  0022400563  1610612737  Atlanta    Hawks         ATL    hawks   1630700
# 4  0022400563  1610612737  Atlanta    Hawks         ATL    hawks   1630811
#
#   firstName familyName       nameI  ... assists steals blocks turnovers  \
# 0       Vít     Krejčí   V. Krejčí  ...       6      0      2         1
# 1     David      Roddy    D. Roddy  ...       2      3      0         1
# 2     Clint     Capela   C. Capela  ...       1      0      1         0
# 3     Dyson    Daniels  D. Daniels  ...       3      3      1         2
# 4    Keaton    Wallace  K. Wallace  ...       6      4      0         1
#
#   foulsPersonal  points  plusMinusPoints     GAME_ID   GAME_DATE  \
# 0             1      11             21.0  0022400563  2025-01-15
# 1             0       4              7.0  0022400563  2025-01-15
# 2             2      11              8.0  0022400563  2025-01-15
# 3             1      18              9.0  0022400563  2025-01-15
# 4             3      27             29.0  0022400563  2025-01-15
#
#        TEAM_NAME
# 0  Atlanta Hawks
# 1  Atlanta Hawks
# 2  Atlanta Hawks
# 3  Atlanta Hawks
# 4  Atlanta Hawks
#
# [5 rows x 37 columns]

# %%
# merge datasets on GAME_ID
merged_df = pd.merge(player_stats_df, games_df, 
                     left_on=['gameId', 'teamId'],
                     right_on=['GAME_ID','TEAM_ID'], 
                     suffixes=('', '_game'), 
                     how='left')

# drop duplicate columns
merged_df.drop(columns=['gameId', 'teamId'], inplace=True)

# save and view
merged_df.to_csv(f'merged_stats_{season_id}.csv', index=False)
merged_df.head(8)
# Out:
#   teamCity teamName teamTricode teamSlug  personId firstName  familyName  \
# 0  Atlanta    Hawks         ATL    hawks   1630249       Vít      Krejčí
# 1  Atlanta    Hawks         ATL    hawks   1631223     David       Roddy
# 2  Atlanta    Hawks         ATL    hawks    203991     Clint      Capela
# 3  Atlanta    Hawks         ATL    hawks   1630700     Dyson     Daniels
# 4  Atlanta    Hawks         ATL    hawks   1630811    Keaton     Wallace
# 5  Atlanta    Hawks         ATL    hawks   1630168    Onyeka     Okongwu
# 6  Atlanta    Hawks         ATL    hawks    203992    Bogdan  Bogdanović
# 7  Atlanta    Hawks         ATL    hawks   1629726  Garrison     Mathews
#
#            nameI         playerSlug position  ... FT_PCT  OREB  DREB   REB  \
# 0      V. Krejčí         vít-krejčí        F  ...  0.682  14.0  37.0  51.0
# 1       D. Roddy        david-roddy        F  ...  0.682  14.0  37.0  51.0
# 2      C. Capela       clint-capela        C  ...  0.682  14.0  37.0  51.0
# 3     D. Daniels      dyson-daniels        G  ...  0.682  14.0  37.0  51.0
# 4     K. Wallace     keaton-wallace        G  ...  0.682  14.0  37.0  51.0
# 5     O. Okongwu     onyeka-okongwu           ...  0.682  14.0  37.0  51.0
# 6  B. Bogdanović  bogdan-bogdanović           ...  0.682  14.0  37.0  51.0
# 7     G. Mathews   garrison-mathews           ...  0.682  14.0  37.0  51.0
#
#     AST   STL  BLK  TOV    PF  PLUS_MINUS
# 0  28.0  11.0  5.0  9.0  15.0        16.0
# 1  28.0  11.0  5.0  9.0  15.0        16.0
# 2  28.0  11.0  5.0  9.0  15.0        16.0
# 3  28.0  11.0  5.0  9.0  15.0        16.0
# 4  28.0  11.0  5.0  9.0  15.0        16.0
# 5  28.0  11.0  5.0  9.0  15.0        16.0
# 6  28.0  11.0  5.0  9.0  15.0        16.0
# 7  28.0  11.0  5.0  9.0  15.0        16.0
#
# [8 rows x 63 columns]

# %%
merged_df.columns
# Out:
# Index(['teamCity', 'teamName', 'teamTricode', 'teamSlug', 'personId',
#        'firstName', 'familyName', 'nameI', 'playerSlug', 'position', 'comment',
#        'jerseyNum', 'minutes', 'fieldGoalsMade', 'fieldGoalsAttempted',
#        'fieldGoalsPercentage', 'threePointersMade', 'threePointersAttempted',
#        'threePointersPercentage', 'freeThrowsMade', 'freeThrowsAttempted',
#        'freeThrowsPercentage', 'reboundsOffensive', 'reboundsDefensive',
#        'reboundsTotal', 'assists', 'steals', 'blocks', 'turnovers',
#        'foulsPersonal', 'points', 'plusMinusPoints', 'GAME_ID', 'GAME_DATE',
#        'TEAM_NAME', 'SEASON_ID', 'TEAM_ID', 'TEAM_ABBREVIATION',
#        'TEAM_NAME_game', 'GAME_ID_game', 'GAME_DATE_game', 'MATCHUP', 'WL',
#        'MIN', 'PTS', 'FGM', 'FGA', 'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT', 'FTM',
#        'FTA', 'FT_PCT', 'OREB', 'DREB', 'REB', 'AST', 'STL', 'BLK', 'TOV',
#        'PF', 'PLUS_MINUS'],
#       dtype='object')

# %% [markdown]
# ## Data Preprocessing

# %%
# get rolling averages for players for each game
# sort data by game date
merged_df = merged_df.sort_values(by=['personId', 'GAME_DATE'])

# get list of stats to average
roll_list = ['minutes', 'fieldGoalsMade', 'fieldGoalsAttempted',
       'fieldGoalsPercentage', 'threePointersMade', 'threePointersAttempted',
       'threePointersPercentage', 'freeThrowsMade', 'freeThrowsAttempted',
       'freeThrowsPercentage', 'reboundsOffensive', 'reboundsDefensive',
       'reboundsTotal', 'assists', 'steals', 'blocks', 'turnovers',
       'foulsPersonal', 'points', 'plusMinusPoints']

# change minutes column to numeric
# merged_df['MIN'] = (
#     merged_df['MIN']
#     .str.split(':').str[0] 
#     .astype(float)           
# )

# generate player rolling stats
for stat in roll_list:
    merged_df[f'ROLLING_{stat}'] = merged_df.groupby('personId')[stat].rolling(5, min_periods=1).mean().reset_index(level=0, drop=True)

merged_df.head(6)

# %%
len(merged_df)
# Out:
# 16066

# %%
# get detailed shot chart data and clutch data
from nba_api.stats.endpoints import shotchartdetail, commonteamyears, commonallplayers

players = commonallplayers.CommonAllPlayers(is_only_current_season=1).get_data_frames()[0]
player_team_map = players[['PERSON_ID', 'TEAM_ID']].drop_duplicates()

shot_chart_data = []
clutch_data = []

for _, row in player_team_map.iterrows():
    try:
        player_id = row['PERSON_ID']
        team_id = row['TEAM_ID']

        scd = shotchartdetail.ShotChartDetail(team_id=team_id,
                                            player_id=player_id,
                                            season_type_all_star='Regular Season',
                                            context_measure_simple='FGA')
        scd_data = scd.get_data_frames()[0]

        player_overalls = scd_data.groupby('PLAYER_ID').agg(
            total_shots=('SHOT_ATTEMPTED_FLAG', 'sum'),
            total_makes=('SHOT_MADE_FLAG', 'sum'),
            fg_pct=('SHOT_MADE_FLAG', lambda x: x.sum() / len(x) if len(x) > 0 else 0),
            paint_shots=('SHOT_ZONE_BASIC', lambda x: (x == 'Restricted Area').sum()),
            mid_range_shots=('SHOT_ZONE_BASIC', lambda x: (x == 'Mid-Range').sum()),
            three_point_shots=('SHOT_ZONE_BASIC', lambda x: (x == 'Above the Break 3').sum()),
            avg_distance=('SHOT_DISTANCE', 'mean'),
        ).reset_index()

        shot_chart_data.append(player_overalls)

        scd_c = shotchartdetail.ShotChartDetail(team_id=team_id,
                                            player_id=player_id,
                                            season_type_all_star='Regular Season',
                                            context_measure_simple='FGA',
                                            clutch_time_nullable='Last 5 Minutes')
        
        scd_c_data = scd_c.get_data_frames()[0]
        
        player_overalls_c = scd_c_data.groupby('PLAYER_ID').agg(
            total_shots_clutch=('SHOT_ATTEMPTED_FLAG', 'sum'),
            total_makes_clutch=('SHOT_MADE_FLAG', 'sum'),
            fg_pct_clutch=('SHOT_MADE_FLAG', lambda x: x.sum() / len(x) if len(x) > 0 else 0),
            paint_shots_clutch=('SHOT_ZONE_BASIC', lambda x: (x == 'Restricted Area').sum()),
            mid_range_shots_clutch=('SHOT_ZONE_BASIC', lambda x: (x == 'Mid-Range').sum()),
            three_point_shots_clutch=('SHOT_ZONE_BASIC', lambda x: (x == 'Above the Break 3').sum()),
            avg_distance_clutch=('SHOT_DISTANCE', 'mean'),
        ).reset_index()

        clutch_data.append(player_overalls_c)
    except Exception as e:
        print(f'{e}: error fetching player {player_id}')

shot_chart_data = pd.concat(shot_chart_data, ignore_index=True)
clutch_data = pd.concat(clutch_data, ignore_index=True)

shot_data = pd.merge(shot_chart_data, clutch_data, on='PLAYER_ID', how='left')

shot_data.head()
# Out:
# HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30): error fetching player 1642271
# HTTPSConnectionPool(host='stats.nba.com', port=443): Max retries exceeded with url: /stats/shotchartdetail?AheadBehind=&ClutchTime=&ContextFilter=&ContextMeasure=FGA&DateFrom=&DateTo=&EndPeriod=&EndRange=&GameID=&GameSegment=&LastNGames=0&LeagueID=00&Location=&Month=0&OpponentTeamID=0&Outcome=&Period=0&PlayerID=1631204&PlayerPosition=&PointDiff=&Position=&RangeType=&RookieYear=&Season=&SeasonSegment=&SeasonType=Regular+Season&StartPeriod=&StartRange=&TeamID=1610612765&VsConference=&VsDivision= (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x16ad67b60>, 'Connection to stats.nba.com timed out. (connect timeout=30)')): error fetching player 1631204
# /var/folders/vl/05t5ksb558l04dj_v01x4f4r0000gn/T/ipykernel_47668/845230661.py:55: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   shot_chart_data = pd.concat(shot_chart_data, ignore_index=True)
# /var/folders/vl/05t5ksb558l04dj_v01x4f4r0000gn/T/ipykernel_47668/845230661.py:56: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   clutch_data = pd.concat(clutch_data, ignore_index=True)
#   PLAYER_ID total_shots total_makes    fg_pct paint_shots mid_range_shots  \
# 0   1630173         141          76  0.539007          91               5
# 1    203500          86          50  0.581395          60               0
# 2   1628389         617         288  0.466775         158              88
# 3   1630534         350         179  0.511429         153               5
# 4   1630583         429         211  0.491841         121              20
#
#   three_point_shots  avg_distance total_shots_clutch total_makes_clutch  \
# 0                 3      5.347518                  7                  4
# 1                 0      2.953488                  3                  1
# 2                84     10.380875                 82                 47
# 3                63     12.545714                 30                 21
# 4               136     13.993007                 29                 13
#
#    fg_pct_clutch paint_shots_clutch mid_range_shots_clutch  \
# 0       0.571429                  5                      0
# 1       0.333333                  3                      0
# 2       0.573171                 23                     13
# 3       0.700000                 19                      0
# 4       0.448276                 13                      2
#
#   three_point_shots_clutch  avg_distance_clutch
# 0                        1             7.285714
# 1                        0             1.666667
# 2                       14            10.902439
# 3                        3             8.566667
# 4                        8            10.344828

# %%
shot_chart_data
# Out:
#     PLAYER_ID total_shots total_makes    fg_pct paint_shots mid_range_shots  \
# 0     1630173          99          51  0.515152          60               2
# 1      203500          52          31  0.596154          39               0
# 2     1628389         533         242  0.454034         140              67
# 3     1630534         329         167  0.507599         146               5
# 4     1630583         377         188  0.498674         109              18
# ..        ...         ...         ...       ...         ...             ...
# 508   1629027         684         275  0.402047         110              71
# 509   1627826         447         275  0.615213         243              12
# 510   1641783         327         134  0.409786          96              15
# 511   1628427           7           4  0.571429           5               0
# 512    203967          54          18  0.333333          18               3
#
#     three_point_shots  avg_distance
# 0                   2      5.717172
# 1                   0      2.403846
# 2                  74     10.294559
# 3                  59     12.370821
# 4                 118     13.840849
# ..                ...           ...
# 508               299     17.067251
# 509                 0      3.921700
# 510                95     14.348624
# 511                 1      8.285714
# 512                20     13.592593
#
# [513 rows x 8 columns]

# %%
merged_df.head()
# Out:
#           teamCity teamName teamTricode teamSlug  personId firstName  \
# 13098  Los Angeles   Lakers         LAL   lakers      2544    LeBron
# 13070  Los Angeles   Lakers         LAL   lakers      2544    LeBron
# 13045  Los Angeles   Lakers         LAL   lakers      2544    LeBron
# 13008  Los Angeles   Lakers         LAL   lakers      2544    LeBron
# 3292   Los Angeles   Lakers         LAL   lakers      2544    LeBron
#
#       familyName     nameI    playerSlug position  ... FT_PCT  OREB  DREB  \
# 13098      James  L. James  lebron-james        F  ...  0.840  15.0  31.0
# 13070      James  L. James  lebron-james        F  ...  0.744   6.0  31.0
# 13045      James  L. James  lebron-james        F  ...  0.875  13.0  32.0
# 13008      James  L. James  lebron-james        F  ...  0.722  11.0  35.0
# 3292       James  L. James  lebron-james        F  ...  0.848   5.0  32.0
#
#         REB   AST   STL  BLK   TOV    PF  PLUS_MINUS
# 13098  46.0  22.0   7.0  8.0   7.0  22.0         7.0
# 13070  37.0  33.0  10.0  5.0  12.0  18.0         7.0
# 13045  45.0  32.0   8.0  3.0  19.0  19.0         4.0
# 13008  46.0  25.0   5.0  6.0  11.0  19.0        -4.0
# 3292   37.0  21.0   6.0  0.0  20.0   7.0       -24.0
#
# [5 rows x 63 columns]

# %%
shot_data[shot_data['PLAYER_ID'] == 2544]
# Out:
#     PLAYER_ID total_shots total_makes  fg_pct paint_shots mid_range_shots  \
# 210      2544         800         410  0.5125         243             145
#
#     three_point_shots  avg_distance total_shots_clutch total_makes_clutch  \
# 210               227      12.92125                 83                 42
#
#      fg_pct_clutch paint_shots_clutch mid_range_shots_clutch  \
# 210       0.506024                 26                     19
#
#     three_point_shots_clutch  avg_distance_clutch
# 210                       25             14.26506

# %%
# rename player id for merged df so it can be merged with shot chart data
merged_df = merged_df.rename(columns={'personId': 'PLAYER_ID'})
merged_df.head()
# Out:
#           teamCity teamName teamTricode teamSlug  PLAYER_ID firstName  \
# 13098  Los Angeles   Lakers         LAL   lakers       2544    LeBron
# 13070  Los Angeles   Lakers         LAL   lakers       2544    LeBron
# 13045  Los Angeles   Lakers         LAL   lakers       2544    LeBron
# 13008  Los Angeles   Lakers         LAL   lakers       2544    LeBron
# 3292   Los Angeles   Lakers         LAL   lakers       2544    LeBron
#
#       familyName     nameI    playerSlug position  ... FT_PCT  OREB  DREB  \
# 13098      James  L. James  lebron-james        F  ...  0.840  15.0  31.0
# 13070      James  L. James  lebron-james        F  ...  0.744   6.0  31.0
# 13045      James  L. James  lebron-james        F  ...  0.875  13.0  32.0
# 13008      James  L. James  lebron-james        F  ...  0.722  11.0  35.0
# 3292       James  L. James  lebron-james        F  ...  0.848   5.0  32.0
#
#         REB   AST   STL  BLK   TOV    PF  PLUS_MINUS
# 13098  46.0  22.0   7.0  8.0   7.0  22.0         7.0
# 13070  37.0  33.0  10.0  5.0  12.0  18.0         7.0
# 13045  45.0  32.0   8.0  3.0  19.0  19.0         4.0
# 13008  46.0  25.0   5.0  6.0  11.0  19.0        -4.0
# 3292   37.0  21.0   6.0  0.0  20.0   7.0       -24.0
#
# [5 rows x 63 columns]

# %%
# perform merge
merged_df = pd.merge(merged_df, shot_data, on='PLAYER_ID', how='left')
merged_df.fillna(0, inplace=True)

merged_df.head()
# Out:
# /var/folders/vl/05t5ksb558l04dj_v01x4f4r0000gn/T/ipykernel_47668/3129978357.py:3: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   merged_df.fillna(0, inplace=True)
#       teamCity teamName teamTricode teamSlug  PLAYER_ID firstName familyName  \
# 0  Los Angeles   Lakers         LAL   lakers       2544    LeBron      James
# 1  Los Angeles   Lakers         LAL   lakers       2544    LeBron      James
# 2  Los Angeles   Lakers         LAL   lakers       2544    LeBron      James
# 3  Los Angeles   Lakers         LAL   lakers       2544    LeBron      James
# 4  Los Angeles   Lakers         LAL   lakers       2544    LeBron      James
#
#       nameI    playerSlug position  ... mid_range_shots three_point_shots  \
# 0  L. James  lebron-james        F  ...             145               227
# 1  L. James  lebron-james        F  ...             145               227
# 2  L. James  lebron-james        F  ...             145               227
# 3  L. James  lebron-james        F  ...             145               227
# 4  L. James  lebron-james        F  ...             145               227
#
#   avg_distance  total_shots_clutch  total_makes_clutch  fg_pct_clutch  \
# 0     12.92125                  83                  42       0.506024
# 1     12.92125                  83                  42       0.506024
# 2     12.92125                  83                  42       0.506024
# 3     12.92125                  83                  42       0.506024
# 4     12.92125                  83                  42       0.506024
#
#    paint_shots_clutch  mid_range_shots_clutch  three_point_shots_clutch  \
# 0                  26                      19                        25
# 1                  26                      19                        25
# 2                  26                      19                        25
# 3                  26                      19                        25
# 4                  26                      19                        25
#
#    avg_distance_clutch
# 0             14.26506
# 1             14.26506
# 2             14.26506
# 3             14.26506
# 4             14.26506
#
# [5 rows x 77 columns]

# %%
# get advanced metrics

# %%
# get rolling averages for players for each game
# sort data by game date
merged_df = merged_df.sort_values(by=['PLAYER_ID', 'GAME_DATE'])

# get list of stats to average
roll_list = ['minutes', 'fieldGoalsMade', 'fieldGoalsAttempted',
       'fieldGoalsPercentage', 'threePointersMade', 'threePointersAttempted',
       'threePointersPercentage', 'freeThrowsMade', 'freeThrowsAttempted',
       'freeThrowsPercentage', 'reboundsOffensive', 'reboundsDefensive',
       'reboundsTotal', 'assists', 'steals', 'blocks', 'turnovers',
       'foulsPersonal', 'points', 'plusMinusPoints']

# change minutes column to numeric
# merged_df['MIN'] = (
#     merged_df['MIN']
#     .str.split(':').str[0] 
#     .astype(float)           
# )

# generate player rolling stats
for stat in roll_list:
    merged_df[f'ROLLING_{stat}'] = merged_df.groupby('PLAYER_ID')[stat].rolling(5, min_periods=1).mean().reset_index(level=0, drop=True)

merged_df.head(6)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/Documents/personal_proj/NBAGamePredictor/venv/lib/python3.12/site-packages/pandas/core/window/rolling.py:371, in BaseWindow._prep_values(self, values)
#     370     else:
# --> 371         values = ensure_float64(values)
#     372 except (ValueError, TypeError) as err:
#
# File pandas/_libs/algos_common_helper.pxi:42, in pandas._libs.algos.ensure_float64()
#
# ValueError: could not convert string to float: '34:39'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# File ~/Documents/personal_proj/NBAGamePredictor/venv/lib/python3.12/site-packages/pandas/core/window/rolling.py:452, in BaseWindow._apply_series(self, homogeneous_func, name)
#     451 try:
# --> 452     values = self._prep_values(obj._values)
#     453 except (TypeError, NotImplementedError) as err:
#
# File ~/Documents/personal_proj/NBAGamePredictor/venv/lib/python3.12/site-packages/pandas/core/window/rolling.py:373, in BaseWindow._prep_values(self, values)
#     372 except (ValueError, TypeError) as err:
# --> 373     raise TypeError(f"cannot handle this type -> {values.dtype}") from err
#     375 # Convert inf to nan for C funcs
#
# TypeError: cannot handle this type -> object
#
# The above exception was the direct cause of the following exception:
#
# DataError                                 Traceback (most recent call last)
# Cell In[186], line 22
#      13 # change minutes column to numeric
#      14 # merged_df['MIN'] = (
#      15 #     merged_df['MIN']
#    (...)
#      19
#      20 # generate player rolling stats
#      21 for stat in roll_list:
# ---> 22     merged_df[f'ROLLING_{stat}'] = merged_df.groupby('PLAYER_ID')[stat].rolling(5, min_periods=1).mean().reset_index(level=0, drop=True)
#      24 merged_df.head(6)
#
# File ~/Documents/personal_proj/NBAGamePredictor/venv/lib/python3.12/site-packages/pandas/core/window/rolling.py:2259, in Rolling.mean(self, numeric_only, engine, engine_kwargs)
#    2216 @doc(
#    2217     template_header,
#    2218     create_section_header("Parameters"),
#    (...)
#    2257     engine_kwargs: dict[str, bool] | None = None,
#    2258 ):
# -> 2259     return super().mean(
#    2260         numeric_only=numeric_only,
#    2261         engine=engine,
#    2262         engine_kwargs=engine_kwargs,
#    2263     )
#
# File ~/Documents/personal_proj/NBAGamePredictor/venv/lib/python3.12/site-packages/pandas/core/window/rolling.py:1625, in RollingAndExpandingMixin.mean(self, numeric_only, engine, engine_kwargs)
#    1623         return self._numba_apply(sliding_mean, engine_kwargs)
#    1624 window_func = window_aggregations.roll_mean
# -> 1625 return self._apply(window_func, name="mean", numeric_only=numeric_only)
#
# File ~/Documents/personal_proj/NBAGamePredictor/venv/lib/python3.12/site-packages/pandas/core/window/rolling.py:723, in BaseWindowGroupby._apply(self, func, name, numeric_only, numba_args, **kwargs)
#     715 def _apply(
#     716     self,
#     717     func: Callable[..., Any],
#    (...)
#     721     **kwargs,
#     722 ) -> DataFrame | Series:
# --> 723     result = super()._apply(
#     724         func,
#     725         name,
#     726         numeric_only,
#     727         numba_args,
#     728         **kwargs,
#     729     )
#     730     # Reconstruct the resulting MultiIndex
#     731     # 1st set of levels = group by labels
#     732     # 2nd set of levels = original DataFrame/Series index
#     733     grouped_object_index = self.obj.index
#
# File ~/Documents/personal_proj/NBAGamePredictor/venv/lib/python3.12/site-packages/pandas/core/window/rolling.py:619, in BaseWindow._apply(self, func, name, numeric_only, numba_args, **kwargs)
#     616     return result
#     618 if self.method == "single":
# --> 619     return self._apply_columnwise(homogeneous_func, name, numeric_only)
#     620 else:
#     621     return self._apply_tablewise(homogeneous_func, name, numeric_only)
#
# File ~/Documents/personal_proj/NBAGamePredictor/venv/lib/python3.12/site-packages/pandas/core/window/rolling.py:472, in BaseWindow._apply_columnwise(self, homogeneous_func, name, numeric_only)
#     470 self._validate_numeric_only(name, numeric_only)
#     471 if self._selected_obj.ndim == 1:
# --> 472     return self._apply_series(homogeneous_func, name)
#     474 obj = self._create_data(self._selected_obj, numeric_only)
#     475 if name == "count":
#     476     # GH 12541: Special case for count where we support date-like types
#
# File ~/Documents/personal_proj/NBAGamePredictor/venv/lib/python3.12/site-packages/pandas/core/window/rolling.py:454, in BaseWindow._apply_series(self, homogeneous_func, name)
#     452     values = self._prep_values(obj._values)
#     453 except (TypeError, NotImplementedError) as err:
# --> 454     raise DataError("No numeric types to aggregate") from err
#     456 result = homogeneous_func(values)
#     457 index = self._slice_axis_for_step(obj.index, result)
#
# DataError: No numeric types to aggregate

# %%
numeric_columns = merged_df.select_dtypes(include=['number']).columns
numeric_columns
# Out:
# Index(['PLAYER_ID', 'fieldGoalsMade', 'fieldGoalsAttempted',
#        'fieldGoalsPercentage', 'threePointersMade', 'threePointersAttempted',
#        'threePointersPercentage', 'freeThrowsMade', 'freeThrowsAttempted',
#        'freeThrowsPercentage', 'reboundsOffensive', 'reboundsDefensive',
#        'reboundsTotal', 'assists', 'steals', 'blocks', 'turnovers',
#        'foulsPersonal', 'points', 'plusMinusPoints', 'TEAM_ID', 'MIN', 'PTS',
#        'FGM', 'FGA', 'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA',
#        'FT_PCT', 'OREB', 'DREB', 'REB', 'AST', 'STL', 'BLK', 'TOV', 'PF',
#        'PLUS_MINUS', 'total_shots', 'total_makes', 'fg_pct', 'paint_shots',
#        'mid_range_shots', 'three_point_shots', 'avg_distance',
#        'total_shots_clutch', 'total_makes_clutch', 'fg_pct_clutch',
#        'paint_shots_clutch', 'mid_range_shots_clutch',
#        'three_point_shots_clutch', 'avg_distance_clutch'],
#       dtype='object')

# %%
merged_df.columns
# Out:
# Index(['teamCity', 'teamName', 'teamTricode', 'teamSlug', 'PLAYER_ID',
#        'firstName', 'familyName', 'nameI', 'playerSlug', 'position', 'comment',
#        'jerseyNum', 'minutes', 'fieldGoalsMade', 'fieldGoalsAttempted',
#        'fieldGoalsPercentage', 'threePointersMade', 'threePointersAttempted',
#        'threePointersPercentage', 'freeThrowsMade', 'freeThrowsAttempted',
#        'freeThrowsPercentage', 'reboundsOffensive', 'reboundsDefensive',
#        'reboundsTotal', 'assists', 'steals', 'blocks', 'turnovers',
#        'foulsPersonal', 'points', 'plusMinusPoints', 'GAME_ID', 'GAME_DATE',
#        'TEAM_NAME', 'SEASON_ID', 'TEAM_ID', 'TEAM_ABBREVIATION',
#        'TEAM_NAME_game', 'GAME_ID_game', 'GAME_DATE_game', 'MATCHUP', 'WL',
#        'MIN', 'PTS', 'FGM', 'FGA', 'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT', 'FTM',
#        'FTA', 'FT_PCT', 'OREB', 'DREB', 'REB', 'AST', 'STL', 'BLK', 'TOV',
#        'PF', 'PLUS_MINUS', 'total_shots', 'total_makes', 'fg_pct',
#        'paint_shots', 'mid_range_shots', 'three_point_shots', 'avg_distance',
#        'total_shots_clutch', 'total_makes_clutch', 'fg_pct_clutch',
#        'paint_shots_clutch', 'mid_range_shots_clutch',
#        'three_point_shots_clutch', 'avg_distance_clutch'],
#       dtype='object')

# %%
# get advanced metrics

# effective field goal pct
merged_df['efg'] = (merged_df['fieldGoalsMade'] + 0.5 * merged_df['threePointersMade']) / merged_df['fieldGoalsAttempted']

# true shooting pct
merged_df['ts'] = merged_df['points'] / (2 * (merged_df['fieldGoalsAttempted'] + 0.44 * merged_df['freeThrowsAttempted']))

# usage pct
from nba_api.stats.endpoints import boxscoreusagev3
game_ids = merged_df['GAME_ID'].unique()
usage_data = []

for game_id in game_ids:
    try:
        usage = boxscoreusagev3.BoxScoreUsageV3(game_id=game_id)
        usage_df = usage.get_data_frames()[0]
        usage_df = usage_df[['gameId', 'personId', 'usagePercentage']]
        usage_data.append(usage_df)
        time.sleep(0.5)
    except Exception as e:
        print(f"Error fetching game {game_id}: {e}")

usage_data = pd.concat(usage_data, ignore_index=True)
usage_data.rename(columns={'gameId': 'GAME_ID', 'personId': 'PLAYER_ID'}, inplace=True)

# %%
# usage pct cont.
merged_df = merged_df.merge(usage_data, on=['GAME_ID', 'PLAYER_ID'], how='left')
merged_df.head()
# Out:
#       teamCity teamName teamTricode teamSlug  PLAYER_ID firstName familyName  \
# 0  Los Angeles   Lakers         LAL   lakers       2544    LeBron      James
# 1  Los Angeles   Lakers         LAL   lakers       2544    LeBron      James
# 2  Los Angeles   Lakers         LAL   lakers       2544    LeBron      James
# 3  Los Angeles   Lakers         LAL   lakers       2544    LeBron      James
# 4  Los Angeles   Lakers         LAL   lakers       2544    LeBron      James
#
#       nameI    playerSlug position  ... fg_pct_clutch paint_shots_clutch  \
# 0  L. James  lebron-james        F  ...      0.506024                 26
# 1  L. James  lebron-james        F  ...      0.506024                 26
# 2  L. James  lebron-james        F  ...      0.506024                 26
# 3  L. James  lebron-james        F  ...      0.506024                 26
# 4  L. James  lebron-james        F  ...      0.506024                 26
#
#   mid_range_shots_clutch  three_point_shots_clutch  avg_distance_clutch  \
# 0                     19                        25             14.26506
# 1                     19                        25             14.26506
# 2                     19                        25             14.26506
# 3                     19                        25             14.26506
# 4                     19                        25             14.26506
#
#         efg        ts  win_streak  streak  usagePercentage
# 0  0.468750  0.486618           1       1            0.214
# 1  0.615385  0.635593           2       2            0.232
# 2  0.636364  0.673401           3       3            0.308
# 3  0.285714  0.330529          -1      -1            0.218
# 4  0.730769  0.808458          -2      -2            0.310
#
# [5 rows x 82 columns]

# %%
# win-loss streak
def calculate_streaks(wl_series):
    streak = []
    count = 0
    
    for result in wl_series:
        if result == "W":
            count = count + 1 if count >= 0 else 1
        else:
            count = count - 1 if count <= 0 else -1
        streak.append(count)
    
    return streak

merged_df['streak'] = (
    merged_df.groupby('TEAM_ID')['WL'].transform(calculate_streaks)
)

#
# Out:
#             TEAM_ID   GAME_DATE WL  streak
# 0      1.610613e+09  2024-10-22  W       1
# 1      1.610613e+09  2024-10-25  W       2
# 2      1.610613e+09  2024-10-26  W       3
# 3      1.610613e+09  2024-10-28  L      -1
# 4      1.610613e+09  2024-10-30  L      -2
# ...             ...         ... ..     ...
# 16061  1.610613e+09  2024-12-07  W       2
# 16062  1.610613e+09  2024-12-23  L      -1
# 16063  1.610613e+09  2025-01-06  W       1
# 16064  1.610613e+09  2025-01-09  L      -1
# 16065  1.610613e+09  2025-01-13  L      -2
#
# [16066 rows x 4 columns]
